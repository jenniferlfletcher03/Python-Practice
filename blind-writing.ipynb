# %% [markdown]
# Date: 2026-11-06

# %%
for item in items:
    print(item)

# %%
for item in items:
    print(item)

# %%
for item in items:
    print(item)

# %%
for i, item in enumerate(items):
    print(i, item)

# %%
for i, item in enumerate(items):
    print(i, item)

# %%
for i, item in enumerate(items):
    print(i, item)

# %%
for key, value in my_dict.items()
    print(key, value)

# %%
for key, value in my_dict.items()
    print(key, value)

# %%
for key, value in my_dict.items():
    print(key, value)

# %%
if x > 10:
    do_thing()
elif x > 5:
    do_other_thing()
else:
    do_default()

# %%
if x > 10:
    do_thing()
elif x > 5:
    do_other_thing()
else:
    do_default()

# %%
if x > 10:
    do_thing()
elif x > 5:
    do_other_thing()
else:
    do_default()

# %%
if name not in seen:
    seen.add(name)

# %%
if name not in seen:
    seen.add(name)

# %%
if name not in seen:
    seen.add(name)
