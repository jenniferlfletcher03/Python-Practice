# %% [markdown]
# # Module 06: Boolean Logic + Truthy/Falsy
#
# Booleans are *True* and *False*. Conditional logic (`if`, `else`, `and`, `or`) is built on them. But Python has a clever trick: it lets you use *non-boolean* values in boolean contexts. Understanding **truthy** and **falsy** is the key to reading idioms like `joined or None` from this morning's `extract_text`.
#
# ## The learning loop
#
# Each lesson follows the same structure:
# 1. **Read** a small piece of code
# 2. **Predict** what it will return — *before* running it
# 3. **Run** it and check what actually happened
# 4. **Reflect** in your own words on what you learned
# 5. **Ask** Claude inline using `print_llm_response("...")` if something doesn't make sense
# 6. **Write** — author your own small variant from a blank cell
# 7. **Fix** — debug a deliberately broken version (at the end of the module)
#
# Steps 6–7 are the difference between *recognizing* a pattern when you see it and being able to *use* it and *debug* it yourself.

# %% [markdown]
# *Setup: import helpers*

# %%
from llm_helpers import print_llm_response, get_llm_response

# %% [markdown]
# # Lesson 1: Comparison Operators
#
# Comparison operators produce booleans: `==` (equal to), `!=` (not equal), `<`, `>`, `<=`, `>=`. The result is always either `True` or `False`.

# %% [markdown]
# **🔮 Predict** — what do I think the next code cell will do?
#
# *(write your prediction here, in plain English, before running the code)*

# %%
age = 44

print(age == 44)
print(age == 45)
print(age > 18)
print(age >= 44)
print(age != 30)

# %% [markdown]
# **📝 Reflect** — what did I actually see, and what did I learn?
#
# *(write your reflection here, in your own words, after running)*

# %% [markdown]
# ⚠️ **Common gotcha**: `=` is *assignment* (give this variable that value). `==` is *comparison* (do these two things have equal value?). They are not interchangeable.

# %% [markdown]
# **✍️ Write** — your turn.
#
# In the blank cell below:
# - Pick a number you care about (your age, the year, anything) and assign it to a variable
# - Write four comparisons using `==`, `!=`, `<`, and `>=`
# - Predict each True/False result before you run
#
# Example shape:
# ```python
# my_number = ...
# print(my_number == ...)
# print(my_number != ...)
# print(my_number < ...)
# print(my_number >= ...)
# ```

# %%
# your code here

# %% [markdown]
# **📝 Write-reflect** — what did you predict, what actually printed, and did anything surprise you?

# %% [markdown]
# **🧩 Synthesis** — What's the difference between `=` and `==`? Why does Python use two different symbols for these?
#
# *(write your synthesis here in your own words)*

# %% [markdown]
# # Lesson 2: `and`, `or`, `not`
#
# These are the logical operators that combine booleans:
# - `A and B` → True only if BOTH are True
# - `A or B` → True if EITHER is True (or both)
# - `not A` → flips True to False and vice versa

# %% [markdown]
# **🔮 Predict** — what do I think the next code cell will do?
#
# *(write your prediction here, in plain English, before running the code)*

# %%
is_morning = True
has_coffee = False

print(is_morning and has_coffee)   # both must be true
print(is_morning or has_coffee)    # either is enough
print(not has_coffee)              # flip it
print(is_morning and not has_coffee)  # combine

# %% [markdown]
# **📝 Reflect** — what did I actually see, and what did I learn?
#
# *(write your reflection here, in your own words, after running)*

# %% [markdown]
# **✍️ Write** — your turn.
#
# In the blank cell below:
# - Create two boolean variables describing things about right now (e.g. `is_tired`, `coffee_in_hand`, `kid_napping`, whatever fits)
# - Write three expressions that combine them with `and`, `or`, and `not`
# - Predict each result in your head before running
#
# The point is to practice translating English ("am I tired AND out of coffee?") into Python operators.

# %%
# your code here

# %% [markdown]
# **📝 Write-reflect** — what did you predict, what actually printed, and did anything surprise you?

# %% [markdown]
# **🧩 Synthesis** — Write a one-sentence summary of when to use `and` vs when to use `or`.
#
# *(write your synthesis here in your own words)*

# %% [markdown]
# # Lesson 3: Truthy and Falsy Values
#
# Python doesn't just treat `True` and `False` as booleans in conditional contexts. It treats *any value* as either **truthy** or **falsy**.
#
# **Falsy values** (treated as False in `if` statements):
# - `False`
# - `None`
# - `0` (the integer zero)
# - `""` (the empty string)
# - `[]` (the empty list)
# - `{}` (the empty dict)
#
# **Everything else is truthy** — including non-zero numbers, non-empty strings, non-empty lists, etc.

# %% [markdown]
# ### 3a — Falsy values in `if` statements

# %% [markdown]
# **🔮 Predict** — what do I think the next code cell will do?
#
# *(write your prediction here, in plain English, before running the code)*

# %%
def check(value):
    if value:
        print(f"{value!r} is truthy")
    else:
        print(f"{value!r} is falsy")

check(True)
check(False)
check(None)
check(0)
check("")
check([])
check("hello")
check([1, 2])
check(42)

# %% [markdown]
# **📝 Reflect** — what did I actually see, and what did I learn?
#
# *(write your reflection here, in your own words, after running)*

# %% [markdown]
# **✍️ Write** — your turn.
#
# In the blank cell below:
# - Reuse the `check` function above (or rewrite it — your choice)
# - Call it with at least five values you're unsure about — e.g. `" "` (a single space), `"0"` (the string zero), `0.0` (the float zero), `[0]` (a list containing one zero), `{"key": None}`
# - Predict each one as truthy or falsy *before* running
#
# The interesting ones aren't the obvious truthy/falsy values — they're the ones that *look* like they might be falsy but aren't (or vice versa).

# %%
# your code here

# %% [markdown]
# **📝 Write-reflect** — what did you predict, what actually printed, and did anything surprise you?

# %% [markdown]
# **🧩 Synthesis** — Name three different falsy values in Python and explain why this matters when writing `if` statements.
#
# *(write your synthesis here in your own words)*

# %% [markdown]
# # Lesson 4: Short-Circuit `or` — and the Capstone
#
# This is where this morning's `joined or None` line FINALLY clicks.
#
# When Python evaluates `A or B`:
# - If A is truthy, the whole expression is A (B is never even evaluated)
# - If A is falsy, the whole expression is B
#
# So `joined or None` reads in plain English: *"give me `joined` if it's truthy; otherwise give me `None`."*
#
# After walking through 4a and 4b, you'll write your own function that does the same thing — that's the **capstone** for this module.

# %% [markdown]
# ### 4a — See it in action

# %% [markdown]
# **🔮 Predict** — what do I think the next code cell will do?
#
# *(write your prediction here, in plain English, before running the code)*

# %%
joined = "Hello world"
result = joined or None
print(f"When joined is non-empty: {result!r}")

joined = ""
result = joined or None
print(f"When joined is empty: {result!r}")

# %% [markdown]
# **📝 Reflect** — what did I actually see, and what did I learn?
#
# *(write your reflection here, in your own words, after running)*

# %% [markdown]
# ### 4b — The pattern generalizes
#
# `some_value or fallback` is how you say *"use some_value if it's meaningful, otherwise use the fallback."*

# %% [markdown]
# **🔮 Predict** — what do I think the next code cell will do?
#
# *(write your prediction here, in plain English, before running the code)*

# %%
user_input = ""
name = user_input or "Anonymous"
print(f"Hello, {name}!")

user_input = "Jen"
name = user_input or "Anonymous"
print(f"Hello, {name}!")

# %% [markdown]
# **📝 Reflect** — what did I actually see, and what did I learn?
#
# *(write your reflection here, in your own words, after running)*

# %% [markdown]
# ## Capstone — write your own `or_default`
#
# You're going to author a function that does, in your own code, the thing `joined or None` does inline in `extract_text`.
#
# **Spec — your function `or_default`:**
# - Takes two arguments: `value` and `default`
# - If `value` is truthy, **return** `value`
# - If `value` is falsy, **return** `default`
#
# Use an `if/else` to start. Don't reach for the `or` shortcut yet — we want to *see* the logic explicitly before we collapse it.

# %% [markdown]
# **✍️ Write your version first.**
#
# In the blank cell below, write `or_default`. Then test it with:
#
# ```python
# print(or_default("Jen", "Anonymous"))
# print(or_default("", "Anonymous"))
# print(or_default(None, "Anonymous"))
# print(or_default(0, "no number provided"))
# print(or_default([1, 2, 3], "empty list"))
# print(or_default([], "empty list"))
# ```
#
# Predict each line before running.
#
# **Bonus trace (don't skip):** what does `or_default(None, None)` return? What does `or_default("", 0)` return? Walk through the logic before running.

# %%
# your or_default here, then the test calls

# %% [markdown]
# **📝 Write-reflect** — did it work on the first try? What did the bonus trace teach you about how Python decides between value and default?

# %% [markdown]
# ---
#
# ### Now compare to a reference implementation
#
# Below is one way to write `or_default` — but using the `or` shortcut instead of `if/else`. **Predict** what it does, run it, then compare to YOUR version. Where they differ — is one better, or are they just different styles?

# %%
def or_default(value, default):
    """Return value if it's truthy, otherwise return default."""
    return value or default

# Same tests as before
print(or_default("Jen", "Anonymous"))
print(or_default("", "Anonymous"))
print(or_default(None, "Anonymous"))
print(or_default(0, "no number provided"))
print(or_default([1, 2, 3], "empty list"))
print(or_default([], "empty list"))

# %% [markdown]
# **📝 Reflect** — how does the reference version compare to yours? What did writing the `if/else` version first teach you about what `or` is *actually* doing under the hood?

# %% [markdown]
# 💡 *Stuck or curious? Ask Claude inline:*
#
# ```python
# print_llm_response("Why is `joined or None` such a common idiom in Python? What problem does it solve elegantly?")
# ```

# %% [markdown]
# **🧩 Synthesis** — In my own words: what does `joined or None` actually do, and why was it used at the end of `extract_text` to handle the case of empty assistant messages?
#
# *(write your synthesis here in your own words)*

# %% [markdown]
# # 🔧 Fix (step 7) — Debug a Broken Function
#
# The code below is broken on purpose. **Predict** the bug first — what do you think will happen when this runs? Then run it to confirm, then fix the function so the three test lines print:
#
# ```
# Welcome back, Jen!
# Please log in.
# Please log in.
# ```
#
# When you run it as-is, the FIRST line will surprise you. Pay attention to *why* — the bug is hiding in one tiny operator.
#
# **Bonus:** the bug here is a flavor of mistake that bites people specifically when they're learning about truthy/falsy. In your own words: why is `if username == True:` not the same as `if username:`?

# %% [markdown]
# **🔮 Predict** — before running, what do you think will happen?

# %%
def greet_user(username):
    if username == True:
        return f"Welcome back, {username}!"
    else:
        return "Please log in."

print(greet_user("Jen"))   # we want: Welcome back, Jen!
print(greet_user(""))      # we want: Please log in.
print(greet_user(None))    # we want: Please log in.

# %% [markdown]
# **🔧 Now fix it.** Edit the code cell above so the three test lines print:
#
# ```
# Welcome back, Jen!
# Please log in.
# Please log in.
# ```
#
# Then re-run.
#
# **📝 Fix-reflect** — what was the bug, and what did your prediction get right or miss? Answer the bonus question above too.

# %% [markdown]
# ---
#
# ## 🎉 End of Module 06
#
# You can now:
# - Use comparison operators (==, !=, <, >, etc.)
# - Combine booleans with `and`, `or`, `not`
# - Recognize Python's falsy values (None, 0, "", [], {}, False)
# - Read short-circuit `or` idioms like `joined or None`
# - Spot the `if x == True:` truthy-check bug when you see it
#
# **Next:** Module 07 — String methods (`.strip()`, `.join()`, `.split()`) and escape sequences.
