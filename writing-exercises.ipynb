# %% [markdown]
#  # Python Syntax Drills — Starter Set

# %% [markdown]
# **How to use this:** For each pattern — copy it 3 times while looking, then close the sheet and write it 3 times from memory. The recall reps are where the reflex forms. If you blank, peek, then try again from memory. Run anything you're unsure about; let the error message be the teacher.
#
# Don't do all of these in one sitting. One tier per session is plenty. When a pattern stops requiring thought, retire it and promote something from your own stumble list.

# %% [markdown]
# ## Tier 1 — The daily chassis
#
# These appear in nearly every Python file ever written.

# %%
# The basic loop

for item in items:
    print(item)

# %%
for item in items:
    print(item)

# %%
for item in items:
    print(item)

# %%
for item in items:
    print(item)

# %%
# Loop with index

for i, item in enumerate(items):
    print(i, item)

# %%
for i, item in enumerate(items):
    print(i, item)

# %%
for i, item in enumerate(items):
    print(i, item)

# %%
for i, item in emumerate(tems)
    print(i, item)

# %%
# Dictionary iteration

for key, value in my_dict.items():
    print(key, value)

# %%
for key, value in my_dict.items():
    print(key, value)

# %%
for key, value in my_dict.items():
    print(key, value)

# %%
for key, value in my_dict.items():
    print(key, value)

# %%
# The conditional family

if x > 10:
    do_thing()
elif x > 5:
    do_other_thing()
else:
    do_default()

# %%
if x > 10"
    do_thing()
elif x> 5:
    do_other_thing()
else:
    do_default()

# %%
if x > 10:
    do_thing()
elif x > 5:
    do_other_thing()
else:
    do_default()

# %%
if x > 10:
    do_thing()
elif x > 5:
    do _other_thing()
else:
    do_default()

# %%
# Membership check

if name not in seen:
    seen.add(name)

# %%
if name not in seen:
    seen.add(name)

# %%
if name not in seen:
    seen.add(name)

# %%
if name not in seen:
    seen.add(name)

# %% [markdown]
# ## Tier 2 — Function and class anatomy
#
# The Fellowship-assessment muscle group. The colon-then-indent move and the `self` rhythm live here.

# %%
# Function with default argument**

def greet(name, greeting="Hello"):
    return f"{greeting}, {name}!"

# %%
# Class skeleton**

class Participant:
    def __init__(self, name, role):
        self.name = name
        self.role = role

    def describe(self):
        return f"{self.name} ({self.role})"

# %%
# Instantiation and method call

p = Participant("Jen", "center")
print(p.describe())

# %%
# List of objects, attribute access**

names = [p.name for p in participants]

# %% [markdown]
# *(Yes, this is a comprehension — the compressed idiom. The uncompressed version is Tier 1, pattern 1. Drill both directions: read this, expand it; write the loop, compress it.)*

# %% [markdown]
# ## Tier 3 — Files, errors, and structure
#
# The patterns that make programs survive contact with reality.

# %%
# File handling

with open(path, "r") as f:
    data = f.read()

# %%
# Writing JSON lines** *(straight out of The Room)

import json

with open(path, "a") as f:
    f.write(json.dumps(record) + "\n")

# %%
# Try/except

try:
    result = risky_thing()
except ValueError as e:
    print(f"Bad value: {e}")

# %%
# The main guard

if __name__ == "__main__":
    main()

# %% [markdown]
# ## Tier 4 — The bracket-stack workout
#
# Pure punctuation drills. These exist solely to train closing things in the right order.

# %%
# Nested structure literal**

config = {
    "model": "claude-sonnet-4",
    "params": {"max_tokens": 1000, "temperature": 0.7},
    "tags": ["test", "drill"],
}

# %%
# Function call with nested args

result = process(load(path), options={"verbose": True})

# %%
# Dict of lists, accessed and appended**

turns_by_speaker = {}
if speaker not in turns_by_speaker:
    turns_by_speaker[speaker] = []
turns_by_speaker[speaker].append(turn)

# %% [markdown]
# ## Deliberate-error round (once per week)
#
# Write each of these *wrong on purpose*, run it, and read the traceback before fixing it. The goal is making error messages legible, not avoiding them.
#
# - Pattern 4 with a missing colon
# - Pattern 7 with `self` left out of a method signature
# - Pattern 14 with one closing brace deleted
# - Pattern 10 with a path that doesn't exist
#
# Write down what Python said each time. You're building a phrasebook for the language errors speak.

# %% [markdown]
# ## Your stumble list
#
# Blank on purpose. When your hands hesitate on something real — in The Room, in practice, anywhere — it goes here and earns drill reps. This section should eventually be longer than mine.
