# %% [markdown]
# # Module 10: Using External Libraries (the embeddings on-ramp)
#
# So far, almost everything you've written used either Python's **built-in** tools (`print`, `len`, `dict`, `json`) or the course's `llm_helpers`. The next rung of the memory system — **semantic search** — needs a tool that is *not* built into Python: an embeddings library (ChromaDB + a small embedding model).
#
# Before we write that code together, this module builds the one idea it stands on: **what it means to install and import an external library**, and how that's different from the built-ins you already know.
#
# > This is a *stub*. Lessons 2+ get filled in with the **real ChromaDB code** once we build it together — so this notebook ends up being the textbook for the system you're actually running.

# %% [markdown]
# ## The learning loop (now 7 steps)
#
# 1. **Read** a small piece of code
# 2. **Predict** what it will do — *before* running it
# 3. **Run** it and check what actually happened
# 4. **Reflect** in your own words
# 5. **Ask** Claude inline (`print_llm_response("...")`) if something doesn't make sense
# 6. **Write** — author a small variant from a blank cell
# 7. **Fix** — debug a deliberately broken version
#
# Steps 6–7 are new. They're the difference between *understanding* code and *being able to write and fix it* — which is the actual Fellowship bar.

# %% [markdown]
# # Lesson 1: Built-in vs. external
#
# Some libraries ship *inside* Python — you can `import` them and they're just there. Others have to be **installed first** (with `pip`) before `import` can find them.
#
# **Read** the cell below. **Predict:** which import works right now, and which one errors — and what the error will be called?

# %%
import json        # built-in: always available
print("json imported fine:", json.dumps({"hello": "world"}))

# Now an external one that is NOT installed yet.
# Predict what happens on the next line before you run it:
import chromadb
print("chromadb imported fine")

# %% [markdown]
# **Reflect:** What was the error called? That exact error name is the single most common thing you'll hit when using external libraries — recognizing it on sight is half the battle.
#
# (We'll *fix* it in Lesson 2 by installing the library — that's the `pip` step, coming when we build the embeddings code together.)

# %% [markdown]
# ## ✍️ Write (step 6)
#
# From the blank cell below, **author from scratch** (don't copy Lesson 1):
# - import a built-in library you know (`math` is a good one),
# - use one thing from it (e.g. `math.sqrt(144)`),
# - print the result with a short label.
#
# Predict the output first, then run.

# %%
# your code here

# %% [markdown]
# ---
#
# ### Now compare to a reference implementation
#
# Below is one way to do the Write task. **Predict** what it does, run it, then compare to YOUR version. Where they differ — is one better, or are they just different styles?

# %%
import math
print("sqrt of 144:", math.sqrt(144))

# Bonus — math has constants too, not just functions
print("pi to 4 places:", round(math.pi, 4))

# %% [markdown]
# **📝 Reflect** — how does the reference compare to yours? If yours used a different function from `math` (e.g. `math.factorial`, `math.log`), even better — it shows you can navigate a library, not just copy the example.

# %% [markdown]
# ## 🔧 Fix (step 7)
#
# The cell below is **broken on purpose**. Read it, predict the error, run it to confirm, then fix it so it prints the square root of 144. (Hint: one of these is not how you spell the function.)

# %%
import maths
print("sqrt of 144 is", maths.squareroot(144))
